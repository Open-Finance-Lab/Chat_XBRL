# %% [markdown]
# # Functions

# %%
import requests
from xml.etree import ElementTree

def get_cik(ticker):
    company_name = ticker
    session = requests.Session()
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
    })

    base_url = "https://www.sec.gov/cgi-bin/browse-edgar"
    params = {
        "action": "getcompany",
        "CIK": ticker,
        "output": "xml"
    }

    response = session.get(base_url, params=params)

    print(f"URL used for request: {response.url}")
    print(f"Response Status Code: {response.status_code}")

    if response.status_code == 200:
        root = ElementTree.fromstring(response.content)
        cik_element = root.find('.//CIK')
        if cik_element is not None:
            if company_name == 'shortName not found':
                company_name = root.find('.//name').text
            return cik_element.text, company_name
        else:
            return "CIK not found", company_name
    else:
        return "Request failed with status code " + str(response.status_code), company_name

# # Example usage
ticker_symbol = "META"
cik_number, company_name = get_cik(ticker_symbol)
print(f"CIK Number for {company_name}: {cik_number}")
print(f"Ticker Symbol for {company_name}: {ticker_symbol}")
# Out:
# URL used for request: https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=META&output=xml
# Response Status Code: 200
# CIK Number for META: 0001326801
# Ticker Symbol for META: META

# %%
import requests
from bs4 import BeautifulSoup

def load_10k_xbrl(cik_num=None):
    if cik_num is None:
        print("CIK number is required.")
        return []

    url_to_all_10k = f"https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={cik_num}&type=10-K&dateb=&owner=include&count=40&search_text="


    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
    }

    try:
        response = requests.get(url_to_all_10k, headers=headers)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find('table', class_='tableFile2')

        if table:
            full_links = []
            for row in table.find_all('tr')[1:]:  # Skipping the header row
                cols = row.find_all('td')
                if len(cols) > 3:
                    filing_type = cols[0].text.strip()
                    filing_date = cols[3].text.strip()

                    if filing_type == '10-K':
                        doc_link = cols[1].find('a', href=True)['href']
                        full_links.append(f"https://www.sec.gov{doc_link}")
            if full_links:
                return full_links
            else:
                print("No 10-K filings found.")
                return []
        else:
            print("No table found on the SEC page.")
            return []
    except requests.RequestException as e:
        print(f"Network error: {e}")
        return []

# # Example usage
# urls = load_10k_xbrl(cik_number, ["2019","2020","2021","2022", "2023"])
# print(urls)

# %%
import requests
from bs4 import BeautifulSoup
import os
import re
from urllib.parse import urljoin

# Function to get XBRL file links from the given SEC page link
def get_xbrl_links(link):
    session = requests.Session()  # Start a new session
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
    }
    session.headers.update(headers)  # Set headers for the session

    response = session.get(link)  # Get the content of the SEC page
    print(f"Accessing URL: {link}")
    print(f"Status Code: {response.status_code}")

    file_links = []  # List to store the XBRL file links
    folder_name = None

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')  # Parse the page content

        for a_tag in soup.find_all('a', href=True):
            file_link = urljoin(link, a_tag['href'])  # Create full URL for the file link

            if file_link.endswith(('.xml', '.xsd')):  # Check if the link is a downloadable file
                print(f"Found file link: {file_link}")
                folder_name_new = file_link.split('/')[-1]
                folder_name_new = re.split(r'[._]', folder_name_new)[0]

                if folder_name is None:
                    folder_name = folder_name_new

                file_links.append(file_link)  # Add the file link to the list
    else:
        print("Failed to retrieve the webpage")

    return file_links, folder_name

# Function to download a file given its link
def download_file(session, file_link, folder_name):
    for attempt in range(3):  # Try to download up to 3 times
        file_response = session.get(file_link)
        if file_response.status_code == 200:
            file_name = file_link.split('/')[-1]
            file_path = os.path.join(folder_name, file_name)
            with open(file_path, 'wb') as file:
                file.write(file_response.content)  # Write the file content
            print(f"Downloaded: {file_path}")
            return file_path
        else:
            print(file_response.status_code)
            print(f"Failed to download file: {file_link} (Attempt {attempt + 1})")
    return None

# Main function to handle the downloading of SEC files
def download_sec_files(link, download_dir):
    file_links, folder_name = get_xbrl_links(link)  # Get XBRL links

    if not file_links:
        print("No files to download")
        return folder_name, None

    session = requests.Session()  # Start a new session
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
    }
    session.headers.update(headers)  # Set headers for the session

    if not os.path.exists(os.path.join(download_dir, folder_name)):
        os.makedirs(os.path.join(download_dir, folder_name))  # Create folder if it doesn't exist

    xbrl_name = None

    for file_link in file_links:
        downloaded_file_path = download_file(session, file_link, os.path.join(download_dir, folder_name))
        if downloaded_file_path and '_htm.xml' in downloaded_file_path:
            xbrl_name = downloaded_file_path  # Update xbrl_name if the file is the main XBRL file

    return folder_name, xbrl_name

# Example usage
# download_dir = os.path.abspath("downloads")  # Define your download directory
# sec_link = 'https://www.sec.gov/Archives/edgar/data/1326801/000132680124000012/0001326801-24-000012-index.htm'

# folder, xbrl_file = download_sec_files(urls[1], download_dir)
# print(f"Folder: {folder}, XBRL File: {xbrl_file}")

# %% [markdown]
# # Example Usage

# %%
''' cik_number;
print(f"CIK Number for {cik_number}")
cik_number = '0001326801'
urls = load_10k_xbrl(cik_number)
print(f"URLs for {company_name}: {urls}") '''

input_file_path = '/content/3_test.txt'

''' print(f"CIK Number for {cik_number}")
cik_number = '0001326801'
urls = load_10k_xbrl(cik_number)
print(f"URLs for {company_name}: {urls}")

#download_dir = '.'  # Current working directory
download_dir = '/content'
for url in (urls):
  folder, xbrl_file = download_sec_files(url, download_dir)
  print(f"Folder: {folder}, XBRL File: {xbrl_file}") '''

try:
    with open(input_file_path, 'r') as file:
        # Loop through each line in the file
        for line in file:
            cik_number = line.strip()  # Remove any leading/trailing whitespace
            print("CIK NUMBER CHANGED TO {}".format(cik_number))
            print(f"CIK Number for {cik_number}")
            urls = load_10k_xbrl(cik_number)
            print(f"URLs for {company_name}: {urls}")

            sub_dir = cik_number
            parent_dir = "/content"

            full_path = os.path.join(parent_dir, sub_dir)

            # Create the subdirectory
            os.mkdir(full_path)

            #download_dir = '.'  # Current working directory
            download_dir = full_path
            for url in (urls):
              folder, xbrl_file = download_sec_files(url, download_dir)
              print(f"Folder: {folder}, XBRL File: {xbrl_file}")


except FileNotFoundError:
    print(f'Error: The file "{input_file_path}" was not found.')
except Exception as e:
    print(f'An error occurred: {e}')

''' download_dir = '.'  # Current working directory
for url in (urls):
  folder, xbrl_file = download_sec_files(url, download_dir)
  print(f"Folder: {folder}, XBRL File: {xbrl_file}") '''
# Out:
# CIK NUMBER CHANGED TO 0001842461
# CIK Number for 0001842461
# No 10-K filings found.
# URLs for META: []
# CIK NUMBER CHANGED TO 0001652044
# CIK Number for 0001652044
# URLs for META: ['https://www.sec.gov/Archives/edgar/data/1652044/000165204424000022/0001652044-24-000022-index.htm', 'https://www.sec.gov/Archives/edgar/data/1652044/000165204423000016/0001652044-23-000016-index.htm', 'https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/0001652044-22-000019-index.htm', 'https://www.sec.gov/Archives/edgar/data/1652044/000165204421000010/0001652044-21-000010-index.htm', 'https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/0001652044-20-000008-index.htm', 'https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/0001652044-19-000004-index.htm', 'https://www.sec.gov/Archives/edgar/data/1652044/000165204418000007/0001652044-18-000007-index.htm', 'https://www.sec.gov/Archives/edgar/data/1652044/000165204417000008/0001652044-17-000008-index.htm', 'https://www.sec.gov/Archives/edgar/data/1652044/000165204416000012/0001652044-16-000012-index.htm']
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204424000022/0001652044-24-000022-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204424000022/goog-20231231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204424000022/goog-20231231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204424000022/goog-20231231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204424000022/goog-20231231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204424000022/goog-20231231_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204424000022/goog-20231231_htm.xml
# Downloaded: /content/META0001652044/goog-20231231/goog-20231231.xsd
# Downloaded: /content/META0001652044/goog-20231231/goog-20231231_cal.xml
# Downloaded: /content/META0001652044/goog-20231231/goog-20231231_def.xml
# Downloaded: /content/META0001652044/goog-20231231/goog-20231231_lab.xml
# Downloaded: /content/META0001652044/goog-20231231/goog-20231231_pre.xml
# Downloaded: /content/META0001652044/goog-20231231/goog-20231231_htm.xml
# Folder: goog-20231231, XBRL File: /content/META0001652044/goog-20231231/goog-20231231_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204423000016/0001652044-23-000016-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204423000016/goog-20221231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204423000016/goog-20221231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204423000016/goog-20221231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204423000016/goog-20221231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204423000016/goog-20221231_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204423000016/goog-20221231_htm.xml
# Downloaded: /content/META0001652044/goog-20221231/goog-20221231.xsd
# Downloaded: /content/META0001652044/goog-20221231/goog-20221231_cal.xml
# Downloaded: /content/META0001652044/goog-20221231/goog-20221231_def.xml
# Downloaded: /content/META0001652044/goog-20221231/goog-20221231_lab.xml
# Downloaded: /content/META0001652044/goog-20221231/goog-20221231_pre.xml
# Downloaded: /content/META0001652044/goog-20221231/goog-20221231_htm.xml
# Folder: goog-20221231, XBRL File: /content/META0001652044/goog-20221231/goog-20221231_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/0001652044-22-000019-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/goog-20211231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/goog-20211231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/goog-20211231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/goog-20211231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/goog-20211231_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/goog-20211231_htm.xml
# Downloaded: /content/META0001652044/goog-20211231/goog-20211231.xsd
# Downloaded: /content/META0001652044/goog-20211231/goog-20211231_cal.xml
# Downloaded: /content/META0001652044/goog-20211231/goog-20211231_def.xml
# Downloaded: /content/META0001652044/goog-20211231/goog-20211231_lab.xml
# Downloaded: /content/META0001652044/goog-20211231/goog-20211231_pre.xml
# Downloaded: /content/META0001652044/goog-20211231/goog-20211231_htm.xml
# Folder: goog-20211231, XBRL File: /content/META0001652044/goog-20211231/goog-20211231_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204421000010/0001652044-21-000010-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204421000010/goog-20201231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204421000010/goog-20201231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204421000010/goog-20201231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204421000010/goog-20201231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204421000010/goog-20201231_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204421000010/goog-20201231_htm.xml
# Downloaded: /content/META0001652044/goog-20201231/goog-20201231.xsd
# Downloaded: /content/META0001652044/goog-20201231/goog-20201231_cal.xml
# Downloaded: /content/META0001652044/goog-20201231/goog-20201231_def.xml
# Downloaded: /content/META0001652044/goog-20201231/goog-20201231_lab.xml
# Downloaded: /content/META0001652044/goog-20201231/goog-20201231_pre.xml
# Downloaded: /content/META0001652044/goog-20201231/goog-20201231_htm.xml
# Folder: goog-20201231, XBRL File: /content/META0001652044/goog-20201231/goog-20201231_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/0001652044-20-000008-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/goog-20191231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/goog-20191231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/goog-20191231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/goog-20191231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/goog-20191231_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/goog10-k2019_htm.xml
# Downloaded: /content/META0001652044/goog-20191231/goog-20191231.xsd
# Downloaded: /content/META0001652044/goog-20191231/goog-20191231_cal.xml
# Downloaded: /content/META0001652044/goog-20191231/goog-20191231_def.xml
# Downloaded: /content/META0001652044/goog-20191231/goog-20191231_lab.xml
# Downloaded: /content/META0001652044/goog-20191231/goog-20191231_pre.xml
# Downloaded: /content/META0001652044/goog-20191231/goog10-k2019_htm.xml
# Folder: goog-20191231, XBRL File: /content/META0001652044/goog-20191231/goog10-k2019_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/0001652044-19-000004-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/goog-20181231.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/goog-20181231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/goog-20181231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/goog-20181231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/goog-20181231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/goog-20181231_pre.xml
# Downloaded: /content/META0001652044/goog-20181231/goog-20181231.xml
# Downloaded: /content/META0001652044/goog-20181231/goog-20181231.xsd
# Downloaded: /content/META0001652044/goog-20181231/goog-20181231_cal.xml
# Downloaded: /content/META0001652044/goog-20181231/goog-20181231_def.xml
# Downloaded: /content/META0001652044/goog-20181231/goog-20181231_lab.xml
# Downloaded: /content/META0001652044/goog-20181231/goog-20181231_pre.xml
# Folder: goog-20181231, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204418000007/0001652044-18-000007-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204418000007/goog-20171231.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204418000007/goog-20171231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204418000007/goog-20171231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204418000007/goog-20171231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204418000007/goog-20171231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204418000007/goog-20171231_pre.xml
# Downloaded: /content/META0001652044/goog-20171231/goog-20171231.xml
# Downloaded: /content/META0001652044/goog-20171231/goog-20171231.xsd
# Downloaded: /content/META0001652044/goog-20171231/goog-20171231_cal.xml
# Downloaded: /content/META0001652044/goog-20171231/goog-20171231_def.xml
# Downloaded: /content/META0001652044/goog-20171231/goog-20171231_lab.xml
# Downloaded: /content/META0001652044/goog-20171231/goog-20171231_pre.xml
# Folder: goog-20171231, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204417000008/0001652044-17-000008-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204417000008/goog-20161231.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204417000008/goog-20161231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204417000008/goog-20161231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204417000008/goog-20161231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204417000008/goog-20161231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1652044/000165204417000008/goog-20161231_pre.xml
# Downloaded: /content/META0001652044/goog-20161231/goog-20161231.xml
# Downloaded: /content/META0001652044/goog-20161231/goog-20161231.xsd
# Downloaded: /content/META0001652044/goog-20161231/goog-20161231_cal.xml
# Downloaded: /content/META0001652044/goog-20161231/goog-20161231_def.xml
# Downloaded: /content/META0001652044/goog-20161231/goog-20161231_lab.xml
# Downloaded: /content/META0001652044/goog-20161231/goog-20161231_pre.xml
# Folder: goog-20161231, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204416000012/0001652044-16-000012-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1288776/000165204416000012/goog-20151231.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1288776/000165204416000012/goog-20151231.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1288776/000165204416000012/goog-20151231_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1288776/000165204416000012/goog-20151231_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1288776/000165204416000012/goog-20151231_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1288776/000165204416000012/goog-20151231_pre.xml
# Downloaded: /content/META0001652044/goog-20151231/goog-20151231.xml
# Downloaded: /content/META0001652044/goog-20151231/goog-20151231.xsd
# Downloaded: /content/META0001652044/goog-20151231/goog-20151231_cal.xml
# Downloaded: /content/META0001652044/goog-20151231/goog-20151231_def.xml
# Downloaded: /content/META0001652044/goog-20151231/goog-20151231_lab.xml
# Downloaded: /content/META0001652044/goog-20151231/goog-20151231_pre.xml
# Folder: goog-20151231, XBRL File: None
# CIK NUMBER CHANGED TO 0001045810
# CIK Number for 0001045810
# URLs for META: ['https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/0001045810-23-000017-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/0001045810-22-000036-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/0001045810-21-000010-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/0001045810-20-000010-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/0001045810-19-000023-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/0001045810-18-000010-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/0001045810-17-000027-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/0001045810-16-000205-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/0001045810-15-000036-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/0001045810-14-000030-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/0001045810-13-000008-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/0001045810-12-000013-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/0001045810-11-000015-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/0001045810-10-000006-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581009000013/0001045810-09-000013-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581008000011/0001045810-08-000011-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581007000008/0001045810-07-000008-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581006000014/0001045810-06-000014-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581005000008/0001045810-05-000008-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104581004000007/0001045810-04-000007-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000104596903001196/0001045969-03-001196-index.htm', 'https://www.sec.gov/Archives/edgar/data/1045810/000101287002002262/0001012870-02-002262-index.htm']
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_htm.xml
# Downloaded: /content/META0001045810/nvda-20240128/nvda-20240128.xsd
# Downloaded: /content/META0001045810/nvda-20240128/nvda-20240128_cal.xml
# Downloaded: /content/META0001045810/nvda-20240128/nvda-20240128_def.xml
# Downloaded: /content/META0001045810/nvda-20240128/nvda-20240128_lab.xml
# Downloaded: /content/META0001045810/nvda-20240128/nvda-20240128_pre.xml
# Downloaded: /content/META0001045810/nvda-20240128/nvda-20240128_htm.xml
# Folder: nvda-20240128, XBRL File: /content/META0001045810/nvda-20240128/nvda-20240128_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/0001045810-23-000017-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129_htm.xml
# Downloaded: /content/META0001045810/nvda-20230129/nvda-20230129.xsd
# Downloaded: /content/META0001045810/nvda-20230129/nvda-20230129_cal.xml
# Downloaded: /content/META0001045810/nvda-20230129/nvda-20230129_def.xml
# Downloaded: /content/META0001045810/nvda-20230129/nvda-20230129_lab.xml
# Downloaded: /content/META0001045810/nvda-20230129/nvda-20230129_pre.xml
# Downloaded: /content/META0001045810/nvda-20230129/nvda-20230129_htm.xml
# Folder: nvda-20230129, XBRL File: /content/META0001045810/nvda-20230129/nvda-20230129_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/0001045810-22-000036-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130_htm.xml
# Downloaded: /content/META0001045810/nvda-20220130/nvda-20220130.xsd
# Downloaded: /content/META0001045810/nvda-20220130/nvda-20220130_cal.xml
# Downloaded: /content/META0001045810/nvda-20220130/nvda-20220130_def.xml
# Downloaded: /content/META0001045810/nvda-20220130/nvda-20220130_lab.xml
# Downloaded: /content/META0001045810/nvda-20220130/nvda-20220130_pre.xml
# Downloaded: /content/META0001045810/nvda-20220130/nvda-20220130_htm.xml
# Folder: nvda-20220130, XBRL File: /content/META0001045810/nvda-20220130/nvda-20220130_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/0001045810-21-000010-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131_htm.xml
# Downloaded: /content/META0001045810/nvda-20210131/nvda-20210131.xsd
# Downloaded: /content/META0001045810/nvda-20210131/nvda-20210131_cal.xml
# Downloaded: /content/META0001045810/nvda-20210131/nvda-20210131_def.xml
# Downloaded: /content/META0001045810/nvda-20210131/nvda-20210131_lab.xml
# Downloaded: /content/META0001045810/nvda-20210131/nvda-20210131_pre.xml
# Downloaded: /content/META0001045810/nvda-20210131/nvda-20210131_htm.xml
# Folder: nvda-20210131, XBRL File: /content/META0001045810/nvda-20210131/nvda-20210131_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/0001045810-20-000010-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-20200126_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-20200126.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-20200126_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-20200126_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-20200126_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-2020x10k_htm.xml
# Downloaded: /content/META0001045810/nvda-20200126/nvda-20200126_lab.xml
# Downloaded: /content/META0001045810/nvda-20200126/nvda-20200126.xsd
# Downloaded: /content/META0001045810/nvda-20200126/nvda-20200126_cal.xml
# Downloaded: /content/META0001045810/nvda-20200126/nvda-20200126_pre.xml
# Downloaded: /content/META0001045810/nvda-20200126/nvda-20200126_def.xml
# Downloaded: /content/META0001045810/nvda-20200126/nvda-2020x10k_htm.xml
# Folder: nvda-20200126, XBRL File: /content/META0001045810/nvda-20200126/nvda-2020x10k_htm.xml
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/0001045810-19-000023-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/nvda-20190127_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/nvda-20190127_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/nvda-20190127.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/nvda-20190127_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/nvda-20190127_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/nvda-20190127.xml
# Downloaded: /content/META0001045810/nvda-20190127/nvda-20190127_def.xml
# Downloaded: /content/META0001045810/nvda-20190127/nvda-20190127_pre.xml
# Downloaded: /content/META0001045810/nvda-20190127/nvda-20190127.xsd
# Downloaded: /content/META0001045810/nvda-20190127/nvda-20190127_cal.xml
# Downloaded: /content/META0001045810/nvda-20190127/nvda-20190127_lab.xml
# Downloaded: /content/META0001045810/nvda-20190127/nvda-20190127.xml
# Folder: nvda-20190127, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/0001045810-18-000010-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/nvda-20180128_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/nvda-20180128_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/nvda-20180128.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/nvda-20180128_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/nvda-20180128_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/nvda-20180128.xml
# Downloaded: /content/META0001045810/nvda-20180128/nvda-20180128_def.xml
# Downloaded: /content/META0001045810/nvda-20180128/nvda-20180128_pre.xml
# Downloaded: /content/META0001045810/nvda-20180128/nvda-20180128.xsd
# Downloaded: /content/META0001045810/nvda-20180128/nvda-20180128_cal.xml
# Downloaded: /content/META0001045810/nvda-20180128/nvda-20180128_lab.xml
# Downloaded: /content/META0001045810/nvda-20180128/nvda-20180128.xml
# Folder: nvda-20180128, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/0001045810-17-000027-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/nvda-20170129.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/nvda-20170129.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/nvda-20170129_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/nvda-20170129_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/nvda-20170129_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/nvda-20170129_pre.xml
# Downloaded: /content/META0001045810/nvda-20170129/nvda-20170129.xml
# Downloaded: /content/META0001045810/nvda-20170129/nvda-20170129.xsd
# Downloaded: /content/META0001045810/nvda-20170129/nvda-20170129_cal.xml
# Downloaded: /content/META0001045810/nvda-20170129/nvda-20170129_def.xml
# Downloaded: /content/META0001045810/nvda-20170129/nvda-20170129_lab.xml
# Downloaded: /content/META0001045810/nvda-20170129/nvda-20170129_pre.xml
# Folder: nvda-20170129, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/0001045810-16-000205-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/nvda-20160131.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/nvda-20160131.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/nvda-20160131_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/nvda-20160131_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/nvda-20160131_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/nvda-20160131_pre.xml
# Downloaded: /content/META0001045810/nvda-20160131/nvda-20160131.xml
# Downloaded: /content/META0001045810/nvda-20160131/nvda-20160131.xsd
# Downloaded: /content/META0001045810/nvda-20160131/nvda-20160131_cal.xml
# Downloaded: /content/META0001045810/nvda-20160131/nvda-20160131_def.xml
# Downloaded: /content/META0001045810/nvda-20160131/nvda-20160131_lab.xml
# Downloaded: /content/META0001045810/nvda-20160131/nvda-20160131_pre.xml
# Folder: nvda-20160131, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/0001045810-15-000036-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/nvda-20150125.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/nvda-20150125.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/nvda-20150125_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/nvda-20150125_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/nvda-20150125_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/nvda-20150125_pre.xml
# Downloaded: /content/META0001045810/nvda-20150125/nvda-20150125.xml
# Downloaded: /content/META0001045810/nvda-20150125/nvda-20150125.xsd
# Downloaded: /content/META0001045810/nvda-20150125/nvda-20150125_cal.xml
# Downloaded: /content/META0001045810/nvda-20150125/nvda-20150125_def.xml
# Downloaded: /content/META0001045810/nvda-20150125/nvda-20150125_lab.xml
# Downloaded: /content/META0001045810/nvda-20150125/nvda-20150125_pre.xml
# Folder: nvda-20150125, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/0001045810-14-000030-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/nvda-20140126.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/nvda-20140126.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/nvda-20140126_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/nvda-20140126_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/nvda-20140126_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/nvda-20140126_pre.xml
# Downloaded: /content/META0001045810/nvda-20140126/nvda-20140126.xml
# Downloaded: /content/META0001045810/nvda-20140126/nvda-20140126.xsd
# Downloaded: /content/META0001045810/nvda-20140126/nvda-20140126_cal.xml
# Downloaded: /content/META0001045810/nvda-20140126/nvda-20140126_def.xml
# Downloaded: /content/META0001045810/nvda-20140126/nvda-20140126_lab.xml
# Downloaded: /content/META0001045810/nvda-20140126/nvda-20140126_pre.xml
# Folder: nvda-20140126, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/0001045810-13-000008-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/nvda-20130127.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/nvda-20130127.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/nvda-20130127_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/nvda-20130127_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/nvda-20130127_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/nvda-20130127_pre.xml
# Downloaded: /content/META0001045810/nvda-20130127/nvda-20130127.xml
# Downloaded: /content/META0001045810/nvda-20130127/nvda-20130127.xsd
# Downloaded: /content/META0001045810/nvda-20130127/nvda-20130127_cal.xml
# Downloaded: /content/META0001045810/nvda-20130127/nvda-20130127_def.xml
# Downloaded: /content/META0001045810/nvda-20130127/nvda-20130127_lab.xml
# Downloaded: /content/META0001045810/nvda-20130127/nvda-20130127_pre.xml
# Folder: nvda-20130127, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/0001045810-12-000013-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/nvda-20120129.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/nvda-20120129.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/nvda-20120129_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/nvda-20120129_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/nvda-20120129_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/nvda-20120129_pre.xml
# Downloaded: /content/META0001045810/nvda-20120129/nvda-20120129.xml
# Downloaded: /content/META0001045810/nvda-20120129/nvda-20120129.xsd
# Downloaded: /content/META0001045810/nvda-20120129/nvda-20120129_cal.xml
# Downloaded: /content/META0001045810/nvda-20120129/nvda-20120129_def.xml
# Downloaded: /content/META0001045810/nvda-20120129/nvda-20120129_lab.xml
# Downloaded: /content/META0001045810/nvda-20120129/nvda-20120129_pre.xml
# Folder: nvda-20120129, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/0001045810-11-000015-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/nvda-20110130.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/nvda-20110130.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/nvda-20110130_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/nvda-20110130_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/nvda-20110130_pre.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/nvda-20110130_def.xml
# Downloaded: /content/META0001045810/nvda-20110130/nvda-20110130.xml
# Downloaded: /content/META0001045810/nvda-20110130/nvda-20110130.xsd
# Downloaded: /content/META0001045810/nvda-20110130/nvda-20110130_cal.xml
# Downloaded: /content/META0001045810/nvda-20110130/nvda-20110130_lab.xml
# Downloaded: /content/META0001045810/nvda-20110130/nvda-20110130_pre.xml
# Downloaded: /content/META0001045810/nvda-20110130/nvda-20110130_def.xml
# Folder: nvda-20110130, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/0001045810-10-000006-index.htm
# Status Code: 200
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/nvda-20100131.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/nvda-20100131.xsd
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/nvda-20100131_cal.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/nvda-20100131_def.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/nvda-20100131_lab.xml
# Found file link: https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/nvda-20100131_pre.xml
# Downloaded: /content/META0001045810/nvda-20100131/nvda-20100131.xml
# Downloaded: /content/META0001045810/nvda-20100131/nvda-20100131.xsd
# Downloaded: /content/META0001045810/nvda-20100131/nvda-20100131_cal.xml
# Downloaded: /content/META0001045810/nvda-20100131/nvda-20100131_def.xml
# Downloaded: /content/META0001045810/nvda-20100131/nvda-20100131_lab.xml
# Downloaded: /content/META0001045810/nvda-20100131/nvda-20100131_pre.xml
# Folder: nvda-20100131, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581009000013/0001045810-09-000013-index.htm
# Status Code: 200
# No files to download
# Folder: None, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581008000011/0001045810-08-000011-index.htm
# Status Code: 200
# No files to download
# Folder: None, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581007000008/0001045810-07-000008-index.htm
# Status Code: 200
# No files to download
# Folder: None, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581006000014/0001045810-06-000014-index.htm
# Status Code: 200
# No files to download
# Folder: None, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581005000008/0001045810-05-000008-index.htm
# Status Code: 200
# No files to download
# Folder: None, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104581004000007/0001045810-04-000007-index.htm
# Status Code: 200
# No files to download
# Folder: None, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000104596903001196/0001045969-03-001196-index.htm
# Status Code: 200
# No files to download
# Folder: None, XBRL File: None
# Accessing URL: https://www.sec.gov/Archives/edgar/data/1045810/000101287002002262/0001012870-02-002262-index.htm
# Status Code: 200
# No files to download
# Folder: None, XBRL File: None
# ' download_dir = \'.\'  # Current working directory\nfor url in (urls):\n  folder, xbrl_file = download_sec_files(url, download_dir)\n  print(f"Folder: {folder}, XBRL File: {xbrl_file}") '
