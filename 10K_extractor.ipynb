# %% [markdown]
# # Functions

# %%
import requests
from xml.etree import ElementTree

def get_cik(ticker):
    company_name = ticker
    session = requests.Session()
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
    })

    base_url = "https://www.sec.gov/cgi-bin/browse-edgar"
    params = {
        "action": "getcompany",
        "CIK": ticker,
        "output": "xml"
    }

    response = session.get(base_url, params=params)

    print(f"URL used for request: {response.url}")
    print(f"Response Status Code: {response.status_code}")

    if response.status_code == 200:
        root = ElementTree.fromstring(response.content)
        cik_element = root.find('.//CIK')
        if cik_element is not None:
            if company_name == 'shortName not found':
                company_name = root.find('.//name').text
            return cik_element.text, company_name
        else:
            return "CIK not found", company_name
    else:
        return "Request failed with status code " + str(response.status_code), company_name

# # Example usage
ticker_symbol = "META"
cik_number, company_name = get_cik(ticker_symbol)
print(f"CIK Number for {company_name}: {cik_number}")
print(f"Ticker Symbol for {company_name}: {ticker_symbol}")
# Out:
# URL used for request: https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=META&output=xml
# Response Status Code: 200
# CIK Number for META: 0001326801
# Ticker Symbol for META: META

# %%
import requests
from bs4 import BeautifulSoup

def load_10k_xbrl(cik_num=None):
    if cik_num is None:
        print("CIK number is required.")
        return []

    url_to_all_10k = f"https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={cik_num}&type=10-K&dateb=&owner=include&count=100&search_text="


    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
    }

    try:
        response = requests.get(url_to_all_10k, headers=headers)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find('table', class_='tableFile2')

        if table:
            full_links = []
            for row in table.find_all('tr')[1:]:  # Skipping the header row
                cols = row.find_all('td')
                if len(cols) > 3:
                    filing_type = cols[0].text.strip()
                    filing_date = cols[3].text.strip()

                    if filing_type == '10-K':
                        doc_link = cols[1].find('a', href=True)['href']
                        full_links.append(f"https://www.sec.gov{doc_link}")
            if full_links:
                return full_links
            else:
                print("No 10-K filings.")
                return []
        else:
            print("No table found on the SEC page.")
            return []
    except requests.RequestException as e:
        print(f"Network error: {e}")
        return []

# # Example usage
#urls = load_10k_xbrl('0000320193')
#print(urls)
# Out:
# ['https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/0000320193-21-000105-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/0000320193-20-000096-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/0000320193-19-000119-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/0000320193-18-000145-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/0000320193-17-000070-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/0001628280-16-020309-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/0001193125-15-356351-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/0001193125-14-383437-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000119312513416534/0001193125-13-416534-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000119312512444068/0001193125-12-444068-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000119312511282113/0001193125-11-282113-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000119312510238044/0001193125-10-238044-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000119312509214859/0001193125-09-214859-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000119312508224958/0001193125-08-224958-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000104746907009340/0001047469-07-009340-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000110465906084288/0001104659-06-084288-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000110465905058421/0001104659-05-058421-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000104746904035975/0001047469-04-035975-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000104746903041604/0001047469-03-041604-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000104746902007674/0001047469-02-007674-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/000091205700053623/0000912057-00-053623-index.htm', 'https://www.sec.gov/Archives/edgar/data/320193/0000912057-99-010244-index.html', 'https://www.sec.gov/Archives/edgar/data/320193/0001047469-97-006960-index.html', 'https://www.sec.gov/Archives/edgar/data/320193/0000320193-96-000023-index.html', 'https://www.sec.gov/Archives/edgar/data/320193/0000320193-95-000016-index.html', 'https://www.sec.gov/Archives/edgar/data/320193/0000320193-94-000016-index.html']

# %%
import requests
from bs4 import BeautifulSoup
import os
import re
from urllib.parse import urljoin

# Function to get XBRL file links from the given SEC page link
def get_xbrl_links(link):
    session = requests.Session()  # Start a new session
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
    }
    session.headers.update(headers)  # Set headers for the session

    response = session.get(link)  # Get the content of the SEC page
    print(f"Accessing URL: {link}")
    print(f"Status Code: {response.status_code}")

    file_links = []  # List to store the XBRL file links
    folder_name = None

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')  # Parse the page content

        for a_tag in soup.find_all('a', href=True):
            file_link = urljoin(link, a_tag['href'])  # Create full URL for the file link

            if file_link.endswith(('.xml')):  # Check if the link is a downloadable file
                print(f"Found file link: {file_link}")
                folder_name_new = file_link.split('/')[-1]
                folder_name_new = re.split(r'[._]', folder_name_new)[0]

                if folder_name is None:
                    folder_name = folder_name_new

                file_links.append(file_link)  # Add the file link to the list
    else:
        print("Failed to retrieve the webpage")

    return file_links, folder_name

# Function to download a file given its link
def download_file(session, file_link, folder_name):
    for attempt in range(3):  # Try to download up to 3 times
        file_response = session.get(file_link)
        if file_response.status_code == 200:
            file_name = file_link.split('/')[-1]
            file_path = os.path.join(folder_name, file_name)
            with open(file_path, 'wb') as file:
                file.write(file_response.content)  # Write the file content
            print(f"Downloaded: {file_path}")
            return file_path
        else:
            print(file_response.status_code)
            print(f"Failed to download file: {file_link} (Attempt {attempt + 1})")
    return None

# Main function to handle the downloading of SEC files
def download_sec_files(link, download_dir):
    file_links, folder_name = get_xbrl_links(link)  # Get XBRL links

    if not file_links:
        print("No files to download")
        return folder_name, None

    session = requests.Session()  # Start a new session
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
    }
    session.headers.update(headers)  # Set headers for the session

    if not os.path.exists(os.path.join(download_dir, folder_name)):
        os.makedirs(os.path.join(download_dir, folder_name))  # Create folder if it doesn't exist

    xbrl_name = None

    for file_link in file_links:
        downloaded_file_path = download_file(session, file_link, os.path.join(download_dir, folder_name))
        if downloaded_file_path and '_htm.xml' in downloaded_file_path:
            xbrl_name = downloaded_file_path  # Update xbrl_name if the file is the main XBRL file

    return folder_name, xbrl_name

# Example usage
# download_dir = os.path.abspath("downloads")  # Define your download directory
# sec_link = 'https://www.sec.gov/Archives/edgar/data/1326801/000132680124000012/0001326801-24-000012-index.htm'

# folder, xbrl_file = download_sec_files(urls[1], download_dir)
# print(f"Folder: {folder}, XBRL File: {xbrl_file}")

# %% [markdown]
# # Example Usage

# %%
# List of tickers and years

# Loop through each ticker and year to download XBRL files

import json

with open('/content/dataset.json', 'r') as input_file_path:
    cik_list = json.load(input_file_path)

company_info = [(company['CIK'], company['company_name']) for company in cik_list]

for i in company_info:
  print(i[0], i[1])


try:
    #with open(input_file_path, 'r') as file:
        # Loop through each line in the file
        for line in company_info:
            original_dir = os.getcwd()
            cik_number = line[0].strip()  # Remove any leading/trailing whitespace
            print("CIK NUMBER CHANGED TO {}".format(cik_number))
            print(f"CIK Number for {cik_number}")
            urls = load_10k_xbrl(cik_number)
            print(f"URLs for {company_name}: {urls}")

            name = line[1].strip()
            name = name.replace('/', ':')

            sub_dir = cik_number + ' - ' + name

            parent_dir = "/content"

            full_path = os.path.join(parent_dir, sub_dir)

            # Create the subdirectory
            if not os.path.exists(full_path):
              print(f"Creating directory: {full_path}")
              os.mkdir(full_path)

            download_dir = full_path
            for url in (urls):
              folder, xbrl_file = download_sec_files(url, download_dir)
              print(f"Folder: {folder}, XBRL File: {xbrl_file}")

            os.chdir(original_dir)


except FileNotFoundError:
    print(f'Error: The file "{input_file_path}" was not found.')
except Exception as e:
    print(f'An error occurred: {e}')
# Out:
# 0001383735 KERR IRENE C
# 0001919731 KERR JAMES D.
# 0001424359 KERR JAMES R
# 0001371010 KERR JAMES
# 0001319151 KERR JAMIE
# 0001286334 KERR JANET
# 0001435533 KERR JASON M
# 0001645863 KERR JASON S.
# 0000938548 KERR JEFFREY A
# 0001325418 KERR JOHN C
# 0001220551 KERR JOHN K
# 0001341794 KERR JOHN M
# 0001563360 KERR JOHN REYNOLDS
# 0001777170 KERR JUSTIN
# 0001874854 KERR KAREN E
# 0001774187 KERR KASON
# 0001313065 KERR KATHLEEN F
# 0001549523 KERR KEAGAN J.
# 0001421451 KERR KENNETH ELDER
# 0001373796 KERR MARIO C
# 0001599721 KERREN MAKEFET PENSION & PROVIDENT CENTER - COOPERATIVE SOCIETY LTD. (UNDER SPECIAL MANAGEMENT)
# 0001141185 KERR MCGEE CORP /DE
# 0000055458 KERR MCGEE CHEMICAL WORLDWIDE LLC
# 0000055458 KERR MCGEE CORP
# 0001300173 KERR MCGEE CORP
# 0001141185 KERR MCGEE HOLDCO INC
# 0001302794 KERR MCGEE LLC
# 0000055458 KERR MCGEE OPERATING CORP
# 0000869295 KERR MCGEE ROCKY MOUNTAIN CORP
# 0001163969 KERR MEL
# 0001649004 KERR MELANIE
# 0001681417 KERR MERCEDES
# 0001938943 KERR MICHAEL S
# 0001827021 KERR MICHAEL T.
# 0001726685 KERR MINES INC.
# 0001107003 KERR MORTON N
# 0001849916 KERR PETER
# 0001212151 KERR RICHARD J
# 0001223870 KERR RICHARD L
# 0001258290 KERR ROBERT B
# 0001058158 KERR ROXANE P
# 0001477737 KERR SAMUEL
# 0001424582 KERR SHANNON C
# 0001217369 KERR STEVEN E
# 0001876928 KERR SUSAN
# 0001698030 KERR THOMAS J.
# 0001480228 KERR THOMAS R.
# 0001189146 KERR TODD J
# 0001071782 KERR WILLIAM A FOUNDATION
# 0001549716 KERR WILLIAM B
# 0001284364 KERR WILLIAM ROBERT
# 0001166858 KERR WILLIAM T
# 0001409529 KERR WILLIAM
# 0001601624 KERR, II JAMES Y
# 0000889005 KERR-MCGEE (NEVADA) LLC
# 0001520144 KERR-MCGEE GATHERING LLC
# 0001699285 KERR-MCGEE WORLDWIDE CORP
# 0001980348 KERRA ASHWOOD LP
# 0001660795 KERRANE BRIAN PATRICK
# 0001700842 KERREST JACQUES FREDERIC
# 0001221273 KERREST JACQUES
# 0001848552 KERRET TAL
# 0001164398 KERREY BOB
# 0001179100 KERREY J ROBERT
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001275714 - KERSEY ANDREW E
# CIK NUMBER CHANGED TO 0001457240
# CIK Number for 0001457240
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001457240 - KERSEY CHRISTOPHER W
# CIK NUMBER CHANGED TO 0001595179
# CIK Number for 0001595179
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001595179 - KERSEY HOTEL, LLC
# CIK NUMBER CHANGED TO 0001468926
# CIK Number for 0001468926
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001468926 - KERSEY MARK A
# CIK NUMBER CHANGED TO 0001819248
# CIK Number for 0001819248
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001819248 - KERSEY MELISSA
# CIK NUMBER CHANGED TO 0001022114
# CIK Number for 0001022114
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001022114 - KERSEY, SCILLIA, FORSTER AND BROOKS, INC.
# CIK NUMBER CHANGED TO 0001242550
# CIK Number for 0001242550
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001242550 - KERSHAW DAVID P
# CIK NUMBER CHANGED TO 0001993586
# CIK Number for 0001993586
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001993586 - KERSHAW DAVID
# CIK NUMBER CHANGED TO 0001713397
# CIK Number for 0001713397
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001713397 - KERSHAW JUSTIN A
# CIK NUMBER CHANGED TO 0001420003
# CIK Number for 0001420003
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001420003 - KERSHAW MICHAEL J.
# CIK NUMBER CHANGED TO 0001562870
# CIK Number for 0001562870
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001562870 - KERSHAW NIGEL
# CIK NUMBER CHANGED TO 0001190846
# CIK Number for 0001190846
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001190846 - KERSHAW PETER C
# CIK NUMBER CHANGED TO 0001686179
# CIK Number for 0001686179
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001686179 - KERSHAW THOMAS
# CIK NUMBER CHANGED TO 0001438071
# CIK Number for 0001438071
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001438071 - KERSHNER SECURITIES, LLC
# CIK NUMBER CHANGED TO 0001535384
# CIK Number for 0001535384
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001535384 - KERSHNER TRADING AMERICAS,LLC
# CIK NUMBER CHANGED TO 0000776736
# CIK Number for 0000776736
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0000776736 - KERSHNER TRADING GROUP, LLC
# CIK NUMBER CHANGED TO 0002010195
# CIK Number for 0002010195
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0002010195 - KERSMAN ALEJANDRO EDUARDO
# CIK NUMBER CHANGED TO 0001642264
# CIK Number for 0001642264
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001642264 - KERSPLODY CORP
# CIK NUMBER CHANGED TO 0001024526
# CIK Number for 0001024526
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001024526 - KERSTEIN DAVID L
# CIK NUMBER CHANGED TO 0001796388
# CIK Number for 0001796388
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001796388 - KERSTEIN DAVID
# CIK NUMBER CHANGED TO 0001430959
# CIK Number for 0001430959
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001430959 - KERSTEIN JAMES JOSEPH
# CIK NUMBER CHANGED TO 0001206611
# CIK Number for 0001206611
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001206611 - KERSTEIN PATRICIA MURPHY
# CIK NUMBER CHANGED TO 0001823682
# CIK Number for 0001823682
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001823682 - KERSTEN DIRK
# CIK NUMBER CHANGED TO 0001236030
# CIK Number for 0001236030
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001236030 - KERSTEN GEERT R
# CIK NUMBER CHANGED TO 0001201824
# CIK Number for 0001201824
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001201824 - KERSTEN JAMES E
# CIK NUMBER CHANGED TO 0001274890
# CIK Number for 0001274890
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001274890 - KERSTEN JEFFREY L
# CIK NUMBER CHANGED TO 0001247777
# CIK Number for 0001247777
# No 10-K filings.
# URLs for META: []
# Creating directory: /content/0001247777 - KERSTEN JOHN R

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-5-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
